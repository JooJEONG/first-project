# %% [markdown]
# 구글 코랩에서 깃허브에 공유가 잘 되는지 확인 용도로 만든 코드입니다(사실 코드도 아님).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab Notebooks/my_project/first-project
# Out:
# /content/drive/MyDrive/Colab Notebooks/my_project/first-project

# %%
# !git config --global user.email 'yukijeje@gmail.com'
# !git config --global user.name 'JooJEONG'
